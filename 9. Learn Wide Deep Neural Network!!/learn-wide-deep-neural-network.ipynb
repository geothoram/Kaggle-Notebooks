# %% [markdown]
# > Please read this : I have not included much explaination in this code because they are preety easy to understand. If you are finding anything complex, please let me know i will explain that.
#
# # Introduction
#
# Topics Covered :-
#
# 1. Functional API (Concat Layers)
# 2. Multiple Inputs
# 3. Multiple Outputs
#
# > I am using Keras and Tensorflow to build these models.
#
# ![](https://2.bp.blogspot.com/-wkrmRibw_GM/V3Mg3O3Q0-I/AAAAAAAABG0/Jm3Nl4-VcYIJ44dA5nSz6vpTyCKF2KWQgCKgB/s640/image03.png)
#
# Read more about [Wide Deep Neural Networks](https://ai.googleblog.com/2016/06/wide-deep-learning-better-together-with.html)

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
housing = fetch_california_housing()
type(housing)
# Out:
# sklearn.utils.Bunch

# %%
print(housing['DESCR'])
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %% [markdown]
# > Let us make train and dev set to build our model and I will use test set to evaluate at end.

# %%
X_train_full,X_test,y_train_full,y_test = train_test_split(housing.data,housing.target)
X_train,X_valid,y_train,y_valid = train_test_split(X_train_full,y_train_full)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Functional API
#
# ## Concat Layers
#
# The Keras functional API is a way to create models that is more flexible than the tf.keras.Sequential API. The functional API can handle models with non-linear topology, models with shared layers, and models with multiple inputs or outputs.
#
# The main idea that a deep learning model is usually a directed acyclic graph (DAG) of layers. So the functional API is a way to build graphs of layers.

# %%
from tensorflow import keras

input_ = keras.layers.Input(shape=X_train.shape[1:])
hidden1 = keras.layers.Dense(30, activation="relu")(input_)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_, hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.models.Model(inputs=[input_], outputs=[output])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 30)           270         input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           930         dense[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 38)           0           input_1[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            39          concatenate[0][0]
# ==================================================================================================
# Total params: 1,239
# Trainable params: 1,239
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model,'wide_alpha.png',show_shapes=True)

# %%
model.compile(loss = 'mean_squared_error',optimizer=keras.optimizers.SGD(lr = 1e-3))

# %%
history = model.fit(X_train,y_train,
          epochs = 50,
          validation_data = (X_valid,y_valid))
# Out:
# Epoch 1/50
# 363/363 [==============================] - 1s 2ms/step - loss: 2.0537 - val_loss: 0.7735
# Epoch 2/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.6999 - val_loss: 0.6695
# Epoch 3/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.6334 - val_loss: 0.6297
# Epoch 4/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5986 - val_loss: 0.6030
# Epoch 5/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5741 - val_loss: 0.5839
# Epoch 6/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5536 - val_loss: 0.5672
# Epoch 7/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5399 - val_loss: 0.5538
# Epoch 8/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5267 - val_loss: 0.5451
# Epoch 9/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5165 - val_loss: 0.5343
# Epoch 10/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5082 - val_loss: 0.5298
# Epoch 11/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5027 - val_loss: 0.5237
# Epoch 12/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4972 - val_loss: 0.5190
# Epoch 13/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4895 - val_loss: 0.5108
# Epoch 14/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4881 - val_loss: 0.5081
# Epoch 15/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4829 - val_loss: 0.5050
# Epoch 16/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4794 - val_loss: 0.5014
# Epoch 17/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4740 - val_loss: 0.4969
# Epoch 18/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4730 - val_loss: 0.4937
# Epoch 19/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4697 - val_loss: 0.4908
# Epoch 20/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4658 - val_loss: 0.4912
# Epoch 21/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4651 - val_loss: 0.4870
# Epoch 22/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4621 - val_loss: 0.4845
# Epoch 23/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4596 - val_loss: 0.4826
# Epoch 24/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4583 - val_loss: 0.4807
# Epoch 25/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4565 - val_loss: 0.4795
# Epoch 26/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4538 - val_loss: 0.4766
# Epoch 27/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4521 - val_loss: 0.4758
# Epoch 28/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4488 - val_loss: 0.4759
# Epoch 29/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4482 - val_loss: 0.4722
# Epoch 30/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4465 - val_loss: 0.4709
# Epoch 31/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4450 - val_loss: 0.4693
# Epoch 32/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4433 - val_loss: 0.4689
# Epoch 33/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4417 - val_loss: 0.4675
# Epoch 34/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4401 - val_loss: 0.4650
# Epoch 35/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4385 - val_loss: 0.4636
# Epoch 36/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4376 - val_loss: 0.4632
# Epoch 37/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4362 - val_loss: 0.4622
# Epoch 38/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4352 - val_loss: 0.4594
# Epoch 39/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4339 - val_loss: 0.4579
# Epoch 40/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4331 - val_loss: 0.4570
# Epoch 41/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4310 - val_loss: 0.4569
# Epoch 42/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4299 - val_loss: 0.4554
# Epoch 43/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4286 - val_loss: 0.4532
# Epoch 44/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4280 - val_loss: 0.4535
# Epoch 45/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4271 - val_loss: 0.4523
# Epoch 46/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4250 - val_loss: 0.4504
# Epoch 47/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4245 - val_loss: 0.4491
# Epoch 48/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4229 - val_loss: 0.4486
# Epoch 49/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4220 - val_loss: 0.4468
# Epoch 50/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4208 - val_loss: 0.4469

# %%
fig = plt.figure(dpi = 100,figsize = (5,3))
ax = fig.add_axes([1,1,1,1])
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,len(loss)+1)
ax.plot(epochs,loss,lw = 2,color = 'green',label = 'Loss')
ax.plot(epochs,val_loss,lw = 2,color = 'blue',label = 'Val Loss')
plt.grid(True)
plt.legend()
ax.set(xlabel = 'Number of Epochs',ylabel = 'Loss',title = 'Loss Curve')
plt.show()

# %% [markdown]
# > Now let us predict outcome for first three observation in our test set.

# %%
X_new = X_test[:3]
y_pred = model.predict(X_new)
y_pred
# Out:
# array([[2.2800326],
#        [1.909385 ],
#        [0.6595856]], dtype=float32)

# %% [markdown]
# # Multiple Inputs
#
# Network with multiple inputs, I will overlap some inputs. I will pass 5 features directly to output layer and 6 features to Deep Networks.

# %%
input_A = keras.layers.Input(shape = [5],name = 'wide_input')
input_B = keras.layers.Input(shape = [6],name = 'deep_input')

hidden1 = keras.layers.Dense(30,activation = 'relu')(input_B)
hidden2 = keras.layers.Dense(30,activation='relu')(hidden1)

concat = keras.layers.concatenate([input_A,hidden2])

output = keras.layers.Dense(1)(concat)

model = keras.Model(inputs = [input_A,input_B],outputs = [output])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# deep_input (InputLayer)         [(None, 6)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 30)           210         deep_input[0][0]
# __________________________________________________________________________________________________
# wide_input (InputLayer)         [(None, 5)]          0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 30)           930         dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 35)           0           wide_input[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            36          concatenate_1[0][0]
# ==================================================================================================
# Total params: 1,176
# Trainable params: 1,176
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model,'multi.png',show_shapes=True)

# %%
model.compile(loss = 'mean_squared_error',optimizer=keras.optimizers.SGD(lr = 1e-3))

# %% [markdown]
# > As we are passing two inputs, We need two input set. Let us make that.

# %%
X_train_A, X_train_B = X_train[:, :5], X_train[:, 2:]
X_valid_A, X_valid_B = X_valid[:, :5], X_valid[:, 2:]
X_test_A, X_test_B = X_test[:, :5], X_test[:, 2:]
X_new_A, X_new_B = X_test_A[:3], X_test_B[:3]

# %%
history = model.fit((X_train_A,X_train_B),y_train,
          epochs = 50,
          validation_data = ((X_valid_A,X_valid_B),y_valid))
# Out:
# Epoch 1/50
# 363/363 [==============================] - 1s 2ms/step - loss: 2.3907 - val_loss: 1.0153
# Epoch 2/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.8064 - val_loss: 0.7399
# Epoch 3/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.6620 - val_loss: 0.6615
# Epoch 4/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.6143 - val_loss: 0.6225
# Epoch 5/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.5866 - val_loss: 0.5985
# Epoch 6/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.5686 - val_loss: 0.5820
# Epoch 7/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5543 - val_loss: 0.5679
# Epoch 8/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5423 - val_loss: 0.5570
# Epoch 9/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.5317 - val_loss: 0.5472
# Epoch 10/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.5234 - val_loss: 0.5390
# Epoch 11/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.5146 - val_loss: 0.5313
# Epoch 12/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.5076 - val_loss: 0.5248
# Epoch 13/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.5013 - val_loss: 0.5182
# Epoch 14/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4959 - val_loss: 0.5131
# Epoch 15/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4907 - val_loss: 0.5092
# Epoch 16/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4869 - val_loss: 0.5046
# Epoch 17/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4822 - val_loss: 0.5013
# Epoch 18/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4789 - val_loss: 0.4971
# Epoch 19/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4753 - val_loss: 0.4936
# Epoch 20/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4726 - val_loss: 0.4915
# Epoch 21/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4695 - val_loss: 0.4890
# Epoch 22/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4667 - val_loss: 0.4864
# Epoch 23/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4654 - val_loss: 0.4841
# Epoch 24/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4628 - val_loss: 0.4821
# Epoch 25/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4595 - val_loss: 0.4803
# Epoch 26/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4585 - val_loss: 0.4780
# Epoch 27/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4562 - val_loss: 0.4764
# Epoch 28/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4545 - val_loss: 0.4754
# Epoch 29/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4529 - val_loss: 0.4739
# Epoch 30/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4505 - val_loss: 0.4721
# Epoch 31/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4498 - val_loss: 0.4695
# Epoch 32/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4471 - val_loss: 0.4683
# Epoch 33/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4460 - val_loss: 0.4668
# Epoch 34/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4448 - val_loss: 0.4653
# Epoch 35/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4426 - val_loss: 0.4638
# Epoch 36/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4412 - val_loss: 0.4620
# Epoch 37/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4392 - val_loss: 0.4610
# Epoch 38/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4379 - val_loss: 0.4597
# Epoch 39/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4365 - val_loss: 0.4583
# Epoch 40/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4354 - val_loss: 0.4571
# Epoch 41/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4339 - val_loss: 0.4567
# Epoch 42/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4332 - val_loss: 0.4554
# Epoch 43/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4319 - val_loss: 0.4541
# Epoch 44/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4310 - val_loss: 0.4526
# Epoch 45/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4292 - val_loss: 0.4518
# Epoch 46/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4288 - val_loss: 0.4507
# Epoch 47/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4278 - val_loss: 0.4497
# Epoch 48/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4263 - val_loss: 0.4489
# Epoch 49/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4259 - val_loss: 0.4473
# Epoch 50/50
# 363/363 [==============================] - 1s 1ms/step - loss: 0.4247 - val_loss: 0.4466

# %%
fig = plt.figure(dpi = 100,figsize = (5,3))
ax = fig.add_axes([1,1,1,1])
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,len(loss)+1)
ax.plot(epochs,loss,lw = 2,color = 'green',label = 'Loss')
ax.plot(epochs,val_loss,lw = 2,color = 'blue',label = 'Val Loss')
plt.grid(True)
plt.legend()
ax.set(xlabel = 'Number of Epochs',ylabel = 'Loss',title = 'Loss Curve')
plt.show()

# %%
y_pred = model.predict((X_new_A,X_new_B))
y_pred
# Out:
# array([[2.1336489],
#        [2.0388255],
#        [0.9519583]], dtype=float32)

# %% [markdown]
# # Multiple Outputs
#
# Now build a model with multiple inputs as well as multiple outputs.

# %%
input_A = keras.layers.Input(shape = [5],name = 'wide_input')
input_B = keras.layers.Input(shape = [6],name = 'deep_input')

hidden1 = keras.layers.Dense(30,activation='relu')(input_B)
hidden2 = keras.layers.Dense(30,activation='relu')(hidden1)

concat = keras.layers.concatenate([input_A,hidden2])

output = keras.layers.Dense(1,name = 'main_output')(concat)
aux_output = keras.layers.Dense(1,name = 'aux_output')(hidden2)

model = keras.Model(inputs = [input_A,input_B],outputs = [output,aux_output])

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# deep_input (InputLayer)         [(None, 6)]          0
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 30)           210         deep_input[0][0]
# __________________________________________________________________________________________________
# wide_input (InputLayer)         [(None, 5)]          0
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 30)           930         dense_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 35)           0           wide_input[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 1)            36          concatenate_2[0][0]
# __________________________________________________________________________________________________
# aux_output (Dense)              (None, 1)            31          dense_7[0][0]
# ==================================================================================================
# Total params: 1,207
# Trainable params: 1,207
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model,'complex.png',show_shapes=True)

# %%
model.compile(loss = ['mse','mse'],loss_weights = [0.9,0.1],optimizer='sgd')

# %% [markdown]
# > I am using same target at both outputs , So i am passing y_train multiple times.

# %%
history = model.fit((X_train_A,X_train_B),(y_train,y_train),
          epochs = 50,
          validation_data = ((X_valid_A,X_valid_B),(y_valid,y_valid)))
# Out:
# Epoch 1/50
# 363/363 [==============================] - 1s 2ms/step - loss: 2.1649 - main_output_loss: 2.0943 - aux_output_loss: 2.8000 - val_loss: 0.8855 - val_main_output_loss: 0.8107 - val_aux_output_loss: 1.5591
# Epoch 2/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.9151 - main_output_loss: 0.8512 - aux_output_loss: 1.4902 - val_loss: 0.5731 - val_main_output_loss: 0.4882 - val_aux_output_loss: 1.3369
# Epoch 3/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.5359 - main_output_loss: 0.4606 - aux_output_loss: 1.2136 - val_loss: 0.5181 - val_main_output_loss: 0.4452 - val_aux_output_loss: 1.1743
# Epoch 4/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4994 - main_output_loss: 0.4379 - aux_output_loss: 1.0522 - val_loss: 0.4804 - val_main_output_loss: 0.4192 - val_aux_output_loss: 1.0317
# Epoch 5/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.4557 - main_output_loss: 0.4050 - aux_output_loss: 0.9122 - val_loss: 0.4576 - val_main_output_loss: 0.4094 - val_aux_output_loss: 0.8909
# Epoch 6/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.
50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3236 - main_output_loss: 0.3130 - aux_output_loss: 0.4189 - val_loss: 0.3795 - val_main_output_loss: 0.3701 - val_aux_output_loss: 0.4638
# Epoch 44/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3217 - main_output_loss: 0.3112 - aux_output_loss: 0.4156 - val_loss: 0.3448 - val_main_output_loss: 0.3340 - val_aux_output_loss: 0.4416
# Epoch 45/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3243 - main_output_loss: 0.3143 - aux_output_loss: 0.4139 - val_loss: 0.3649 - val_main_output_loss: 0.3553 - val_aux_output_loss: 0.4516
# Epoch 46/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3218 - main_output_loss: 0.3118 - aux_output_loss: 0.4125 - val_loss: 0.3374 - val_main_output_loss: 0.3264 - val_aux_output_loss: 0.4366
# Epoch 47/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3192 - main_output_loss: 0.3091 - aux_output_loss: 0.4099 - val_loss: 0.3525 - val_main_output_loss: 0.3417 - val_aux_output_loss: 0.4500
# Epoch 48/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3183 - main_output_loss: 0.3084 - aux_output_loss: 0.4072 - val_loss: 0.3531 - val_main_output_loss: 0.3432 - val_aux_output_loss: 0.4416
# Epoch 49/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3181 - main_output_loss: 0.3085 - aux_output_loss: 0.4046 - val_loss: 0.3431 - val_main_output_loss: 0.3328 - val_aux_output_loss: 0.4360
# Epoch 50/50
# 363/363 [==============================] - 1s 2ms/step - loss: 0.3196 - main_output_loss: 0.3100 - aux_output_loss: 0.4052 - val_loss: 0.3355 - val_main_output_loss: 0.3251 - val_aux_output_loss: 0.4292

# %%
pd.DataFrame(history.history).head()
# Out:
#        loss  main_output_loss  aux_output_loss  val_loss  \
# 0  2.164882          2.094315         2.799978  0.885495
# 1  0.915095          0.851190         1.490242  0.573115
# 2  0.535911          0.460612         1.213602  0.518103
# 3  0.499377          0.437947         1.052248  0.480424
# 4  0.455692          0.404973         0.912163  0.457552
#
#    val_main_output_loss  val_aux_output_loss
# 0              0.810650             1.559099
# 1              0.488248             1.336908
# 2              0.445193             1.174295
# 3              0.419176             1.031659
# 4              0.409398             0.890930

# %%
fig = plt.figure(dpi = 100,figsize = (5,3))
ax = fig.add_axes([1,1,1,1])
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1,len(loss)+1)
ax.plot(epochs,loss,lw = 2,color = 'green',label = 'Loss')
ax.plot(epochs,val_loss,lw = 2,color = 'blue',label = 'Val Loss')
plt.grid(True)
plt.legend()
ax.set(xlabel = 'Number of Epochs',ylabel = 'Loss',title = 'Loss Curve')
plt.show()

# %% [markdown]
# > Evaluate returns total_loss, main_loss and aux_loss.

# %%
total_loss,main_loss,aux_loss = model.evaluate((X_test_A,X_test_B),
                                               (y_test,y_test))
# Out:
# 162/162 [==============================] - 0s 1ms/step - loss: 0.3393 - main_output_loss: 0.3295 - aux_output_loss: 0.4274

# %% [markdown]
# > We can also predict at each output.

# %%
y_pred_main,y_pred_aux = model.predict([X_new_A,X_new_B])

# %%
y_pred_main
# Out:
# array([[1.6964865],
#        [1.5565675],
#        [1.0015845]], dtype=float32)

# %%
y_pred_aux
# Out:
# array([[1.3627712],
#        [1.4719335],
#        [1.0232503]], dtype=float32)

# %% [markdown]
# > Thank you for reading my notebook. Let me know how you find this useful. Happy Learning !!
